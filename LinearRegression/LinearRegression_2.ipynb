# %%
import pandas as pd
from pandas import Series, DataFrame
import sklearn as sk
from sklearn.decomposition import PCA
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('/content/sample_data/fish_train.csv')
df
# Out:
#        Species  Weight  Length1  Length2  Length3   Height   Width
# 0        Roach   150.0     20.4     22.0     24.7   5.8045  3.7544
# 1        Perch   250.0     25.4     27.5     28.9   7.2828  4.5662
# 2        Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# 3        Bream   925.0     36.2     39.5     45.3  18.7542  6.7497
# 4        Perch   110.0     19.0     21.0     22.5   5.6925  3.5550
# ..         ...     ...      ...      ...      ...      ...     ...
# 114     Parkki   273.0     23.0     25.0     28.0  11.0880  4.1440
# 115       Pike   500.0     42.0     45.0     48.0   6.9600  4.8960
# 116  Whitefish  1000.0     37.3     40.0     43.5  12.3540  6.5250
# 117      Perch   120.0     20.0     22.0     23.5   6.1100  3.4075
# 118      Perch   820.0     36.6     39.0     41.3  12.4313  7.3514
#
# [119 rows x 7 columns]

# %%
X = df.drop(['Species', 'Weight'], axis = 1)
Y = df['Weight']
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=11, stratify= df.loc[:,'Species'])

# %%
l = LinearRegression().fit(x_train, y_train)
l.score(x_train, y_train)
# Out:
# 0.8952367849888005

# %%
y_predicted = l.predict(x_test)
r2 = r2_score(y_test, y_predicted)
r2
# Out:
# 0.8244231342772975

# %%
pca = PCA(n_components ='mle', svd_solver='full', random_state=11)
ddf = df.drop(['Species'], axis = 1)
centred_data = ddf - ddf.mean()
data = pca.fit_transform(centred_data)
print(ddf.corr())
# Out:
#            Weight   Length1   Length2   Length3    Height     Width
# Weight   1.000000  0.897306  0.900856  0.907401  0.745870  0.896493
# Length1  0.897306  1.000000  0.999457  0.991043  0.621868  0.862072
# Length2  0.900856  0.999457  1.000000  0.993469  0.638003  0.868714
# Length3  0.907401  0.991043  0.993469  1.000000  0.704594  0.872468
# Height   0.745870  0.621868  0.638003  0.704594  1.000000  0.783475
# Width    0.896493  0.862072  0.868714  0.872468  0.783475  1.000000

# %%
pca = PCA(n_components=1, svd_solver='full', random_state = 11)
pca.fit(x_train[['Length1','Length2','Length3']])
print('Доля объясненной дисперсии:', *pca.explained_variance_ratio_)
df['Lengths'] = pca.transform(df[['Length1','Length2','Length3']])
df = df.drop(['Length1','Length2','Length3'], axis = 1)
df
# Out:
# Доля объясненной дисперсии: 0.9960937799357052
#        Species  Weight   Height   Width    Lengths
# 0        Roach   150.0   5.8045  3.7544 -11.179973
# 1        Perch   250.0   7.2828  4.5662  -2.743215
# 2        Bream   430.0  12.4440  5.1340   1.865605
# 3        Bream   925.0  18.7542  6.7497  20.087194
# 4        Perch   110.0   5.6925  3.5550 -13.866121
# ..         ...     ...      ...     ...        ...
# 114     Parkki   273.0  11.0880  4.1440  -6.021302
# 115       Pike   500.0   6.9600  4.8960  28.023118
# 116  Whitefish  1000.0  12.3540  6.5250  19.848407
# 117      Perch   120.0   6.1100  3.4075 -12.137145
# 118      Perch   820.0  12.4313  7.3514  17.536829
#
# [119 rows x 5 columns]

# %%
X = df.drop(['Species', 'Weight'], axis = 1)
Y = df['Weight']
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=11, stratify= df.loc[:,'Species'])
#l = LinearRegression().fit()
l = LinearRegression().fit(x_train, y_train)
y_pred = l.predict(x_test)
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.8207366051929542

# %% [markdown]
# Модификация признаков

# %%
df
# Out:
#        Species  Weight   Height   Width    Lengths
# 0        Roach   150.0   5.8045  3.7544 -11.179973
# 1        Perch   250.0   7.2828  4.5662  -2.743215
# 2        Bream   430.0  12.4440  5.1340   1.865605
# 3        Bream   925.0  18.7542  6.7497  20.087194
# 4        Perch   110.0   5.6925  3.5550 -13.866121
# ..         ...     ...      ...     ...        ...
# 114     Parkki   273.0  11.0880  4.1440  -6.021302
# 115       Pike   500.0   6.9600  4.8960  28.023118
# 116  Whitefish  1000.0  12.3540  6.5250  19.848407
# 117      Perch   120.0   6.1100  3.4075 -12.137145
# 118      Perch   820.0  12.4313  7.3514  17.536829
#
# [119 rows x 5 columns]

# %%
df[['Height', 'Width', 'Lengths']] = df[['Height', 'Width', 'Lengths']] **3
df
# Out:
#        Species  Weight       Height       Width       Lengths
# 0        Roach   150.0   195.566492   52.920218  -1397.404947
# 1        Perch   250.0   386.273710   95.206103    -20.643309
# 2        Bream   430.0  1926.992424  135.321746      6.493200
# 3        Bream   925.0  6596.227555  307.505871   8105.089503
# 4        Perch   110.0   184.462936   44.928179  -2666.029700
# ..         ...     ...          ...         ...           ...
# 114     Parkki   273.0  1363.200233   71.163818   -218.308822
# 115       Pike   500.0   337.153536  117.361115  22006.419543
# 116  Whitefish  1000.0  1885.483738  277.805953   7819.463223
# 117      Perch   120.0   228.099131   39.564674  -1787.926424
# 118      Perch   820.0  1921.098539  397.292313   5393.282877
#
# [119 rows x 5 columns]

# %%
X = df.drop(['Species', 'Weight'], axis = 1)
Y = df['Weight']
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 11, stratify = df.loc[:,'Species'])
l = LinearRegression().fit(x_train, y_train)
y_pred = l.predict(x_test)
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.9701660036773103

# %%
x_train['Width'].mean()
# Out:
# 129.56198433393484

# %%
ddf = df
dummies = pd.get_dummies(ddf['Species'])
ddf = ddf.join(dummies)
X = ddf.drop(['Species', 'Weight'], axis = 1)
Y = ddf['Weight']
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 11, stratify = ddf.loc[:,'Species'])
l = LinearRegression().fit(x_train, y_train)
y_pred = l.predict(x_test)
r2_score(y_test, y_pred)
# Out:
# 0.9679628452773985

# %%
ddf = df
dummies = pd.get_dummies(ddf['Species'], drop_first = True)
ddf = ddf.join(dummies)
X = ddf.drop(['Species', 'Weight'], axis = 1)
Y = ddf['Weight']
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 11, stratify = ddf.loc[:,'Species'])
l = LinearRegression().fit(x_train, y_train)
y_pred = l.predict(x_test)
r2_score(y_test, y_pred)
# Out:
# 0.9679628452773898
