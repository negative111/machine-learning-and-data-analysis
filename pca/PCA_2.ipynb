# %%
import pandas as pd
from pandas import Series, DataFrame
import sklearn
from sklearn.decomposition import PCA
import numpy as np
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt

# %%
z_matrix = pd.read_csv('/content/sample_data/X_reduced_492.csv', delimiter = ';', header = None) # Матрица счетов
p_matrix = pd.read_csv('/content/sample_data/X_loadings_492.csv', delimiter = ';', header = None) # Матрица весов
z_matrix.shape, p_matrix.shape
# Out:
# ((100, 10), (100, 10))

# %%
f_matrix = z_matrix @ p_matrix.T # Центрированное
f_matrix.shape
plt.imshow(f_matrix, cmap = 'gray')
